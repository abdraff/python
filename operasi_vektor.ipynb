# %%
import numpy as np

a = np.array([-3,2,5])
b = np.array([1,2,4])

# %% [markdown]
# Soal nomor 1
#
# ---

# %%
c = a+b
print(c)
# Out:
# [-2  4  9]

# %% [markdown]
# Soal nomor 2

# %%
d = 2*a
print(d)
# Out:
# [-6  4 10]

# %% [markdown]
# Soal nomor 3

# %%
e = b/2
print(e)
# Out:
# [0.5 1.  2. ]

# %% [markdown]
# soal nomor 4 (dot product)

# %%
f = np.dot(a,b)
print(f)
# Out:
# 21

# %% [markdown]
# soal nomor 5 (cross product)

# %%
g = np.cross(a,b)
print(g)
# Out:
# [-2 17 -8]
